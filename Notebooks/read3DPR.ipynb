# %%
fname='/Users/mgrecu/3A-MO.GPM.DPR.V3-20210325.20180601-S000000-E235959.06.V07A.HDF5'
import netCDF4

import numpy as np

with netCDF4.Dataset(fname) as fh:
    precipRate=fh['FS/G1/precipRateESurface/mean'][:]
    count=fh['FS/G1/precipRateESurface/count'][:]
    #print(precipRate)

#print(precipRate.shape)

# %%
import matplotlib.pyplot as plt
plt.plot(precipRate[0,0,0,:,:].mean(axis=0))
plt.plot(precipRate[0,0,1,:,:].mean(axis=0))
